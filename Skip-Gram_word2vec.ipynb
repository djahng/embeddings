# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:15, 1.97MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

# Set the threshold parameter, t
threshold = 0.01

# Get total word counts
word_counts = Counter(int_words)
total_count = len(int_words)

# Calculate the word frequencies, f(w_i)
word_frequencies = {word: count/total_count for word, count in word_counts.items()}

# Calculate the drop probabilities
p_drop = {word: 1 - np.sqrt(threshold / word_frequencies[word]) for word in word_counts}

train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    range = random.randint(1, window_size)
    
    # Get begin and end indices
    start = idx - range
    end = idx + range + 1
    
    # Make sure start and stop indices are within range
    if start < 0:
        start = 0
    if end > len(words):
        end = len(words)
    
    return words[start:end]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 7.8091 0.2632 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 7.2983 0.2575 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.7337 0.2590 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 6.1914 0.2622 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.7819 0.2644 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5634 0.2603 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.3380 0.2589 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.2047 0.2524 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.9899 0.2866 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.8526 0.2748 sec/batch
# Nearest to that: too, promise, celebrity, wives, vagabond, includes, up, without,
# Nearest to not: perhaps, bros, think, parameters, finnish, necessary, been, non,
# Nearest to also: el, maintainer, club, eclipse, control, rouge, defeated, let,
# Nearest to he: responses, holds, sold, caller, marriage, february, legnica, those,
# Nearest to all: materials, talk, functions, powers, attack, world, pastoral, developed,
# Nearest to used: british, yards, implications, abd, posts, mixed, screening, plans,
# Nearest to i: forces, india, furniture, spartan, prejudice, reliefs, alliance, exact,
# Nearest to when: parity, remaining, methods, attest, these, poking, muddle, odense,
# Nearest to woman: idea, minority, odrade, casbah, jordan, creators, hatred, reputed,
# Nearest to dr: citation, pietro, hexafluoride, active, requirements, bratislava, australian, him,
# Nearest to mainly: iceberg, lose, promise, wins, without, laws, leaving, volterra,
# Nearest to scale: nehemiah, blockades, fingerprinting, findlay, neutralist, denotation, governorates, carney,
# Nearest to test: berkeley, iliad, prejudice, helens, rajputs, el, stolpe, romero,
# Nearest to lived: course, eunuch, cinematographers, given, edge, countries, triumph, wishful,
# Nearest to road: uncredited, tosses, reznor, rich, dia, goldsmiths, aided, theodosian,
# Nearest to ocean: schalk, reconciled, tongues, inalienable, length, ties, gauntlets, posed,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.9481 0.2542 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.8852 0.2488 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.8370 0.2500 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.7910 0.2818 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.7503 0.2656 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.7422 0.2661 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.6872 0.2667 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.7107 0.2769 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.6493 0.2660 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.6902 0.2641 sec/batch
# Nearest to that: too, promise, pps, mib, without, cremated, wives, huron,
# Nearest to not: perhaps, parameters, bros, necessary, think, onward, balto, thinly,
# Nearest to also: maintainer, eclipse, el, rouge, chile, resign, club, mathers,
# Nearest to he: responses, caller, academic, holds, desserts, sold, maclean, legnica,
# Nearest to all: materials, talk, adjustment, functions, serpent, monitoring, snake, duplicated,
# Nearest to used: implications, yards, sony, screening, british, posts, integers, proxies,
# Nearest to i: forces, furniture, reliefs, annual, spartan, india, prejudice, bankrupt,
# Nearest to when: parity, poking, makeshift, arabs, bough, governors, mitra, attest,
# Nearest to woman: minority, idea, creators, prevailing, corsican, odrade, reputed, regions,
# Nearest to dr: citation, pietro, thoroughbreds, bratislava, requirements, timothy, hexafluoride, modest,
# Nearest to mainly: iceberg, spaces, promise, wins, criminal, activate, volterra, without,
# Nearest to scale: nehemiah, blockades, fingerprinting, denotation, hunter, copyrightable, midst, carney,
# Nearest to test: rajputs, berkeley, iliad, harold, prejudice, mediterranean, romero, el,
# Nearest to lived: course, occasional, surprise, eunuch, cinematographers, wishful, buying, edge,
# Nearest to road: uncredited, reznor, unclear, goldsmiths, theodosian, aided, tosses, dia,
# Nearest to ocean: schalk, reconciled, tongues, posed, gauntlets, ties, inalienable, length,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.6631 0.2653 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.4682 0.2600 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.6410 0.2687 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.5866 0.2645 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.5615 0.2638 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.5765 0.2661 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.5616 0.2656 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.5002 0.2646 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.4737 0.2644 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.5002 0.2645 sec/batch
# Nearest to that: too, mib, sudden, cremated, pps, toughest, vagabond, huron,
# Nearest to not: perhaps, bros, parameters, does, think, balto, onward, thinly,
# Nearest to also: maintainer, eclipse, rouge, unicameral, el, yielding, chile, workmen,
# Nearest to he: caller, responses, desserts, maclean, him, unarmed, beloved, legnica,
# Nearest to all: materials, adjustment, serpent, functions, talk, duplicated, monitoring, purdue,
# Nearest to used: implications, yards, integers, sony, tomahawk, ewing, british, screening,
# Nearest to i: forces, furniture, annual, intensive, spartan, reliefs, relevance, handful,
# Nearest to when: parity, makeshift, bough, poking, dubai, mcgraw, governors, attest,
# Nearest to woman: idea, odrade, telecast, corsican, minority, prevailing, casbah, quiescent,
# Nearest to dr: citation, pietro, bratislava, timothy, thoroughbreds, modest, hexafluoride, positioned,
# Nearest to mainly: iceberg, spaces, activate, wins, criminal, meat, volterra, promise,
# Nearest to scale: nehemiah, blockades, denotation, primates, fingerprinting, afb, serfdom, carney,
# Nearest to test: berkeley, rajputs, iliad, donors, drops, esoteric, harold, balcony,
# Nearest to lived: cinematographers, eunuch, occasional, idaho, surprise, interactivity, course, sexually,
# Nearest to road: uncredited, goldsmiths, reznor, theodosian, naturalist, unclear, aided, peder,
# Nearest to ocean: posed, schalk, tongues, reconciled, gauntlets, inalienable, hel, slumped,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.5396 0.2676 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.5145 0.2666 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.4862 0.2645 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.4551 0.2643 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.4676 0.2686 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.4560 0.2677 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.3146 0.2798 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.4373 0.2876 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.4675 0.2758 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.3966 0.2538 sec/batch
# Nearest to that: too, mib, pps, sudden, cremated, vagabond, toughest, inviting,
# Nearest to not: does, perhaps, bros, parameters, accommodates, think, coll, emirs,
# Nearest to also: maintainer, unicameral, eclipse, chile, rouge, el, workmen, yielding,
# Nearest to he: caller, him, desserts, maclean, responses, unarmed, obey, beloved,
# Nearest to all: materials, adjustment, monitoring, functions, purdue, duplicated, serpent, adder,
# Nearest to used: integers, yards, implications, sony, tomahawk, effigies, screening, prabang,
# Nearest to i: furniture, intensive, annual, forces, reliefs, relevance, spartan, graves,
# Nearest to when: poking, makeshift, dubai, parity, bough, mcgraw, contemplated, arabs,
# Nearest to woman: corsican, casbah, sonnets, odrade, telecast, quiescent, idea, minority,
# Nearest to dr: citation, pietro, thoroughbreds, timothy, bratislava, hexafluoride, modest, insurgent,
# Nearest to mainly: iceberg, activate, spaces, wins, onslaught, peg, meat, criminal,
# Nearest to scale: nehemiah, blockades, denotation, primates, afb, serfdom, ley, fingerprinting,
# Nearest to test: berkeley, donors, rajputs, romero, stolpe, unfair, iliad, esoteric,
# Nearest to lived: eunuch, interactivity, idaho, cinematographers, surprise, inadvertently, buying, wishful,
# Nearest to road: uncredited, theodosian, reznor, goldsmiths, reflective, naturalist, hildebrand, dia,
# Nearest to ocean: schalk, posed, inalienable, reconciled, gauntlets, tongues, slumped, leeds,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.4265 0.2537 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.4162 0.2497 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.3996 0.2504 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.4387 0.2516 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.3795 0.2505 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.4185 0.2509 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.4096 0.2503 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.4030 0.2496 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.4068 0.2508 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.4114 0.2511 sec/batch
# Nearest to that: mib, too, toughest, pps, cremated, vagabond, revisited, sudden,
# Nearest to not: does, bros, perhaps, parameters, accommodates, emirs, coll, detoxification,
# Nearest to also: maintainer, unicameral, duns, irvine, el, piedmont, mathers, workmen,
# Nearest to he: caller, him, desserts, maclean, legnica, responses, unarmed, beloved,
# Nearest to all: materials, serpent, adjustment, monitoring, purdue, duplicated, insult, functions,
# Nearest to used: integers, yards, sony, screening, frontispiece, effigies, proxies, implications,
# Nearest to i: furniture, t, sensor, annual, forces, intensive, reliefs, spartan,
# Nearest to when: makeshift, poking, dubai, bough, contemplated, affable, parity, kidman,
# Nearest to woman: corsican, odrade, sonnets, casbah, quiescent, tarmac, idea, telecast,
# Nearest to dr: citation, pietro, thoroughbreds, bratislava, insurgent, timothy, dissenters, hexafluoride,
# Nearest to mainly: iceberg, activate, qwerty, onslaught, evangelism, wins, spaces, escorted,
# Nearest to scale: blockades, nehemiah, serfdom, primates, afb, denotation, carney, findlay,
# Nearest to test: rajputs, donors, berkeley, romero, unfair, helens, stolpe, drops,
# Nearest to lived: eunuch, idaho, interactivity, cinematographers, slips, surprise, inadvertently, buying,
# Nearest to road: uncredited, theodosian, reznor, ounces, goldsmiths, naturalist, reflective, peder,
# Nearest to ocean: schalk, posed, inalienable, slumped, reconciled, tongues, gauntlets, leeds,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.3711 0.2524 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.3516 0.2494 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.4097 0.2496 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.4075 0.2501 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.3365 0.2507 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.3352 0.2499 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.3345 0.2502 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.2983 0.2499 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.3687 0.2504 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.3577 0.2500 sec/batch
# Nearest to that: mib, toughest, cremated, pps, vagabond, revisited, remind, too,
# Nearest to not: does, bros, perhaps, accommodates, nightbreed, parameters, emirs, coll,
# Nearest to also: maintainer, mathers, irvine, see, outweigh, flattery, piedmont, dentition,
# Nearest to he: caller, him, legnica, desserts, beloved, maclean, tribesmen, ceau,
# Nearest to all: monitoring, serpent, adjustment, purdue, materials, lydia, functions, insult,
# Nearest to used: integers, commonly, yards, sony, frontispiece, screening, reference, effigies,
# Nearest to i: t, intensive, furniture, sensor, read, spartan, escobar, forces,
# Nearest to when: makeshift, poking, contemplated, bough, ionian, dubai, affable, shelley,
# Nearest to woman: casbah, sonnets, corsican, odrade, tarmac, quiescent, telecast, idea,
# Nearest to dr: citation, pietro, timothy, thoroughbreds, insurgent, hexafluoride, bratislava, rightful,
# Nearest to mainly: iceberg, activate, evangelism, qwerty, wins, lingala, tradeoffs, surreal,
# Nearest to scale: blockades, nehemiah, serfdom, primates, ley, carney, denotation, afb,
# Nearest to test: rajputs, donors, berkeley, helens, romero, stolpe, unfair, esoteric,
# Nearest to lived: interactivity, eunuch, cinematographers, idaho, slips, wishful, buying, surprise,
# Nearest to road: uncredited, theodosian, reznor, ounces, goldsmiths, naturalist, reflective, dia,
# Nearest to ocean: schalk, inalienable, posed, slumped, reconciled, leeds, gauntlets, tongues,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.3732 0.2521 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.3495 0.2497 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.3708 0.2514 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.3300 0.2502 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.2995 0.2502 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.2885 0.2493 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.3268 0.2495 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.2623 0.2492 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.3320 0.2515 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.3196 0.2498 sec/batch
# Nearest to that: mib, vagabond, toughest, cremated, inviting, energies, revisited, postulated,
# Nearest to not: does, bros, did, nightbreed, accommodates, perhaps, swinging, but,
# Nearest to also: see, maintainer, el, pocketing, flattery, mathers, outweigh, irvine,
# Nearest to he: him, caller, beloved, legnica, desserts, marriage, tribesmen, sweating,
# Nearest to all: purdue, monitoring, pollinator, lydia, insult, serpent, adjustment, materials,
# Nearest to used: integers, commonly, screening, yards, sony, frontispiece, effigies, resisters,
# Nearest to i: t, furniture, am, intensive, escobar, sensor, grad, read,
# Nearest to when: makeshift, contemplated, ionian, kidman, poking, dubai, cdot, insufficiently,
# Nearest to woman: sonnets, odrade, casbah, tarmac, corsican, quiescent, idea, telecast,
# Nearest to dr: citation, timothy, hexafluoride, pietro, thoroughbreds, insurgent, bratislava, constantinian,
# Nearest to mainly: iceberg, activate, qwerty, evangelism, lingala, wins, metroid, gulfstream,
# Nearest to scale: blockades, nehemiah, serfdom, primates, carney, ley, denotation, afb,
# Nearest to test: rajputs, helens, donors, romero, stolpe, berkeley, unfair, esoteric,
# Nearest to lived: interactivity, parton, slips, idaho, cinematographers, eunuch, wishful, asmara,
# Nearest to road: uncredited, theodosian, reznor, ounces, goldsmiths, naturalist, reflective, trotskyists,
# Nearest to ocean: schalk, inalienable, posed, leeds, slumped, tongues, dungeons, west,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.3228 0.2519 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.2819 0.2491 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.3239 0.2499 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.3205 0.2497 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.2468 0.2502 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.3134 0.2494 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.2184 0.2517 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.2742 0.2491 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.2784 0.2494 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.1837 0.2495 sec/batch
# Nearest to that: mib, vagabond, toughest, ensuring, inviting, cremated, energies, pps,
# Nearest to not: does, did, accommodates, bros, nightbreed, swinging, but, perhaps,
# Nearest to also: see, mathers, pocketing, el, flattery, maintainer, dentition, outweigh,
# Nearest to he: him, caller, marriage, beloved, nihonshoki, tribesmen, ceau, legnica,
# Nearest to all: serpent, pollinator, monitoring, lydia, insult, purdue, duplicated, monorail,
# Nearest to used: commonly, integers, sony, resisters, effigies, screening, frontispiece, yards,
# Nearest to i: t, am, escobar, sensor, grad, furniture, intensive, barkley,
# Nearest to when: makeshift, contemplated, kidman, ionian, insufficiently, dubai, cdot, poking,
# Nearest to woman: sonnets, corsican, casbah, odrade, quiescent, tarmac, telecast, tchad,
# Nearest to dr: citation, hexafluoride, timothy, thoroughbreds, insurgent, pietro, constantinian, bratislava,
# Nearest to mainly: iceberg, activate, lingala, evangelism, metroid, qwerty, spymaster, gulfstream,
# Nearest to scale: blockades, nehemiah, carney, primates, ley, afb, denotation, serfdom,
# Nearest to test: rajputs, helens, donors, romero, aberdeen, unfair, qurra, drops,
# Nearest to lived: parton, idaho, interactivity, eunuch, cinematographers, slips, wishful, asmara,
# Nearest to road: theodosian, uncredited, reznor, ounces, goldsmiths, trotskyists, naturalist, reflective,
# Nearest to ocean: schalk, inalienable, posed, leeds, slumped, west, dungeons, landing,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.3307 0.2530 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.3037 0.2497 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.2808 0.2496 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 4.2707 0.2499 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.2674 0.2500 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.1904 0.2508 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.2675 0.2498 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.2854 0.2497 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.2948 0.2498 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.2903 0.2492 sec/batch
# Nearest to that: mib, vagabond, cremated, toughest, suggested, retailer, pps, postulated,
# Nearest to not: does, did, bros, accommodates, nightbreed, swinging, but, do,
# Nearest to also: see, pocketing, list, flattery, outweigh, piedmont, el, dentition,
# Nearest to he: him, caller, beloved, nihonshoki, marriage, legnica, tribesmen, celeste,
# Nearest to all: pollinator, purdue, lydia, monitoring, serpent, functions, insult, pissarro,
# Nearest to used: commonly, integers, sony, resisters, effigies, frontispiece, screening, serviced,
# Nearest to i: am, t, sensor, think, you, grad, escobar, hippopotamus,
# Nearest to when: makeshift, contemplated, kidman, ionian, insufficiently, mitra, dubai, poking,
# Nearest to woman: sonnets, corsican, casbah, odrade, quiescent, telecast, tarmac, tchad,
# Nearest to dr: citation, hexafluoride, thoroughbreds, timothy, constantinian, insurgent, pietro, rightful,
# Nearest to mainly: iceberg, activate, evangelism, metroid, lingala, qwerty, spymaster, lg,
# Nearest to scale: blockades, nehemiah, primates, carney, ley, serfdom, auctions, rotors,
# Nearest to test: helens, rajputs, donors, romero, qurra, aberdeen, drops, stolpe,
# Nearest to lived: parton, interactivity, marshland, eunuch, slips, idaho, cinematographers, wishful,
# Nearest to road: theodosian, uncredited, reznor, trotskyists, ounces, goldsmiths, reflective, offbeat,
# Nearest to ocean: schalk, inalienable, posed, slumped, atlantic, leeds, west, landing,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 4.2797 0.2529 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 4.2889 0.2504 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 4.2665 0.2502 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 4.2259 0.2493 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 4.2727 0.2499 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 4.2943 0.2500 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 4.2746 0.2524 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 4.2440 0.2688 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 4.2934 0.2695 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 4.2747 0.2679 sec/batch
# Nearest to that: mib, cremated, toughest, suggested, vagabond, gravimeters, retailer, postulated,
# Nearest to not: does, did, accommodates, nightbreed, but, bros, swinging, do,
# Nearest to also: see, flattery, hipparchus, pocketing, list, blacklisting, piedmont, irvine,
# Nearest to he: caller, him, beloved, nihonshoki, legnica, marriage, celeste, maclean,
# Nearest to all: pollinator, purdue, lydia, serpent, pissarro, monitoring, functions, reappraisal,
# Nearest to used: commonly, effigies, integers, sony, resisters, screening, frontispiece, andreotti,
# Nearest to i: am, t, ii, think, grad, sensor, read, barkley,
# Nearest to when: makeshift, kidman, contemplated, ionian, insufficiently, mitra, dubai, cdot,
# Nearest to woman: sonnets, tarmac, casbah, corsican, quiescent, telecast, tchad, odrade,
# Nearest to dr: citation, hexafluoride, thoroughbreds, insurgent, timothy, constantinian, pietro, rightful,
# Nearest to mainly: iceberg, activate, evangelism, metroid, lingala, spymaster, qwerty, lg,
# Nearest to scale: blockades, nehemiah, primates, carney, ley, large, rotors, neu,
# Nearest to test: helens, donors, rajputs, qurra, drops, aberdeen, romero, stolpe,
# Nearest to lived: parton, marshland, interactivity, slips, eunuch, idaho, informed, haughty,
# Nearest to road: theodosian, uncredited, reznor, ounces, trotskyists, goldsmiths, reflective, offbeat,
# Nearest to ocean: schalk, inalienable, posed, atlantic, slumped, landing, leeds, pacific,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.2529 0.2717 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 4.2922 0.2690 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 4.2879 0.2675 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 4.2366 0.2686 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 4.1461 0.2695 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 4.2351 0.2684 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.2254 0.2696 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 4.1561 0.2682 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.2405 0.2699 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 4.2264 0.2689 sec/batch
# Nearest to that: mib, suggested, proposition, postulated, cremated, forgets, gravimeters, ensuring,
# Nearest to not: does, did, do, accommodates, but, nightbreed, swinging, bros,
# Nearest to also: see, hipparchus, list, pocketing, dentition, flattery, blacklisting, outweigh,
# Nearest to he: him, caller, vengeance, nihonshoki, legnica, beloved, marriage, celeste,
# Nearest to all: pollinator, monitoring, lydia, purdue, reappraisal, crankshaft, functions, serpent,
# Nearest to used: commonly, effigies, integers, sony, widely, serviced, extensively, resisters,
# Nearest to i: am, t, ii, grad, escobar, barkley, think, sensor,
# Nearest to when: makeshift, kidman, contemplated, insufficiently, mitra, ionian, dubai, cdot,
# Nearest to woman: sonnets, tarmac, corsican, casbah, quiescent, tchad, telecast, revivalist,
# Nearest to dr: citation, hexafluoride, thoroughbreds, insurgent, timothy, constantinian, mummy, rightful,
# Nearest to mainly: activate, iceberg, lingala, metroid, evangelism, spymaster, twelver, qwerty,
# Nearest to scale: blockades, nehemiah, large, primates, carney, irradiation, rotors, ley,
# Nearest to test: helens, donors, drops, aberdeen, rajputs, qurra, stolpe, romero,
# Nearest to lived: parton, marshland, idaho, interactivity, informed, wishful, cinematographers, slips,
# Nearest to road: theodosian, uncredited, reznor, ounces, reflective, trotskyists, goldsmiths, naturalist,
# Nearest to ocean: schalk, atlantic, inalienable, posed, pacific, landing, slumped, leeds,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 4.1807 0.2705 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 4.3043 0.2694 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 4.0066 0.2853 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 3.9001 0.2831 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 4.2085 0.2746 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 4.0214 0.2907 sec/batch
# Epoch 1/10 Iteration: 11700 Avg. Training loss: 4.1272 0.2975 sec/batch
# Epoch 1/10 Iteration: 11800 Avg. Training loss: 4.1991 0.2904 sec/batch
# Epoch 1/10 Iteration: 11900 Avg. Training loss: 4.2030 0.2816 sec/batch
# Epoch 1/10 Iteration: 12000 Avg. Training loss: 4.2609 0.2860 sec/batch
# Nearest to that: mib, suggested, cremated, solanas, toughest, vagabond, gravimeters, proposition,
# Nearest to not: does, did, but, accommodates, do, nightbreed, bros, nor,
# Nearest to also: see, hipparchus, pocketing, list, irvine, blacklisting, flattery, el,
# Nearest to he: caller, where, nihonshoki, ceau, him, received, sweating, vengeance,
# Nearest to all: pollinator, lydia, purdue, serpent, pissarro, monorail, heeded, insult,
# Nearest to used: commonly, effigies, sony, serviced, resisters, grozny, integers, term,
# Nearest to i: am, t, ii, think, grad, escobar, tell, read,
# Nearest to when: makeshift, kidman, contemplated, asked, mitra, insufficiently, dubai, ionian,
# Nearest to woman: sonnets, quiescent, tarmac, corsican, casbah, tchad, revivalist, telecast,
# Nearest to dr: citation, thoroughbreds, hexafluoride, constantinian, insurgent, mummy, pietro, kovacs,
# Nearest to mainly: activate, iceberg, spymaster, evangelism, lingala, metroid, qwerty, twelver,
# Nearest to scale: blockades, large, primates, nehemiah, irradiation, rotors, auctions, carney,
# Nearest to test: helens, donors, aberdeen, drops, qurra, stolpe, romero, endosperm,
# Nearest to lived: parton, marshland, interactivity, eunuch, idaho, informed, canonized, cinematographers,
# Nearest to road: theodosian, uncredited, ounces, reznor, naturalist, browning, reflective, gorky,
# Nearest to ocean: schalk, inalienable, atlantic, posed, landing, slumped, leeds, southeast,
# Epoch 1/10 Iteration: 12100 Avg. Training loss: 4.1983 0.2974 sec/batch
# Epoch 1/10 Iteration: 12200 Avg. Training loss: 4.2858 0.2808 sec/batch
# Epoch 1/10 Iteration: 12300 Avg. Training loss: 4.2810 0.2815 sec/batch
# Epoch 1/10 Iteration: 12400 Avg. Training loss: 4.2777 0.3073 sec/batch
# Epoch 1/10 Iteration: 12500 Avg. Training loss: 4.2535 0.2848 sec/batch
# Epoch 1/10 Iteration: 12600 Avg. Training loss: 4.2326 0.2800 sec/batch
# Epoch 1/10 Iteration: 12700 Avg. Training loss: 4.1162 0.2849 sec/batch
# Epoch 1/10 Iteration: 12800 Avg. Training loss: 4.1787 0.2827 sec/batch
# Epoch 1/10 Iteration: 12900 Avg. Training loss: 4.2305 0.2844 sec/batch
# Epoch 1/10 Iteration: 13000 Avg. Training loss: 4.2230 0.2993 sec/batch
# Nearest to that: mib, proposition, suggested, presuppose, cremated, solanas, promotes, vagabond,
# Nearest to not: does, did, but, do, accommodates, nightbreed, necessarily, bros,
# Nearest to also: see, list, hipparchus, piedmont, pocketing, blacklisting, osu, ofc,
# Nearest to he: caller, ceau, him, vengeance, received, where, nihonshoki, maclean,
# Nearest to all: pollinator, purdue, crankshaft, invisibility, lydia, reappraisal, pissarro, ketones,
# Nearest to used: commonly, effigies, extensively, term, sony, integers, serviced, proxies,
# Nearest to i: am, t, ii, think, grad, escobar, you, hippopotamus,
# Nearest to when: makeshift, kidman, contemplated, insufficiently, mitra, ionian, dubai, prioritization,
# Nearest to woman: sonnets, quiescent, tarmac, corsican, casbah, tchad, resident, butyrate,
# Nearest to dr: citation, thoroughbreds, hexafluoride, constantinian, insurgent, rightful, pietro, mummy,
# Nearest to mainly: activate, iceberg, twelver, spymaster, evangelism, lingala, metroid, emulsions,
# Nearest to scale: blockades, large, primates, nehemiah, irradiation, neu, auctions, carney,
# Nearest to test: helens, aberdeen, drops, donors, stolpe, qurra, romero, endosperm,
# Nearest to lived: parton, marshland, interactivity, eunuch, idaho, domini, informed, cinematographers,
# Nearest to road: theodosian, uncredited, ounces, reznor, maneaba, naturalist, browning, reflective,
# Nearest to ocean: schalk, inalienable, posed, landing, atlantic, slumped, leeds, pacific,
# Epoch 1/10 Iteration: 13100 Avg. Training loss: 4.2069 0.2841 sec/batch
# Epoch 1/10 Iteration: 13200 Avg. Training loss: 4.2154 0.2816 sec/batch
# Epoch 1/10 Iteration: 13300 Avg. Training loss: 4.2455 0.2821 sec/batch
# Epoch 1/10 Iteration: 13400 Avg. Training loss: 4.2698 0.2826 sec/batch
# Epoch 1/10 Iteration: 13500 Avg. Training loss: 4.1942 0.2840 sec/batch
# Epoch 1/10 Iteration: 13600 Avg. Training loss: 4.2323 0.2838 sec/batch
# Epoch 1/10 Iteration: 13700 Avg. Training loss: 4.0371 0.2842 sec/batch
# Epoch 1/10 Iteration: 13800 Avg. Training loss: 4.0537 0.2826 sec/batch
# Epoch 1/10 Iteration: 13900 Avg. Training loss: 4.2033 0.2838 sec/batch
# Epoch 1/10 Iteration: 14000 Avg. Training loss: 4.1933 0.2832 sec/batch
# Nearest to that: proposition, mib, suggested, cremated, presuppose, say, argue, retailer,
# Nearest to not: does, did, but, do, necessarily, nightbreed, accommodates, bros,
# Nearest to also: see, list, hipparchus, ofc, blacklisting, pocketing, osu, piedmont,
# Nearest to he: caller, where, him, ceau, tribesmen, immorality, nihonshoki, himself,
# Nearest to all: pollinator, purdue, lydia, insult, invisibility, almost, pissarro, reappraisal,
# Nearest to used: commonly, extensively, effigies, serviced, term, integers, sony, widely,
# Nearest to i: am, ii, think, t, grad, escobar, tell, barkley,
# Nearest to when: makeshift, kidman, contemplated, insufficiently, mitra, sangre, dubai, asked,
# Nearest to woman: sonnets, quiescent, tarmac, tchad, corsican, casbah, butyrate, resident,
# Nearest to dr: citation, insurgent, thoroughbreds, hexafluoride, constantinian, pietro, timothy, mummy,
# Nearest to mainly: activate, iceberg, twelver, lingala, metroid, spymaster, evangelism, emulsions,
# Nearest to scale: blockades, large, primates, nehemiah, auctions, irradiation, neu, carney,
# Nearest to test: helens, drops, endosperm, donors, romero, stolpe, qurra, aberdeen,
# Nearest to lived: parton, marshland, interactivity, eunuch, domini, idaho, slips, scheming,
# Nearest to road: uncredited, theodosian, ounces, reznor, kinetochores, naturalist, reflective, browning,
# Nearest to ocean: schalk, inalienable, atlantic, landing, posed, pacific, slumped, southeast,
# Epoch 1/10 Iteration: 14100 Avg. Training loss: 4.0244 0.2866 sec/batch
# Epoch 1/10 Iteration: 14200 Avg. Training loss: 4.2177 0.3129 sec/batch
# Epoch 1/10 Iteration: 14300 Avg. Training loss: 4.2219 0.2932 sec/batch
# Epoch 1/10 Iteration: 14400 Avg. Training loss: 4.1863 0.2953 sec/batch
# Epoch 1/10 Iteration: 14500 Avg. Training loss: 4.1801 0.2834 sec/batch
# Epoch 1/10 Iteration: 14600 Avg. Training loss: 4.1314 0.2820 sec/batch
# Epoch 1/10 Iteration: 14700 Avg. Training loss: 4.1638 0.2819 sec/batch
# Epoch 1/10 Iteration: 14800 Avg. Training loss: 4.2078 0.2836 sec/batch
# Epoch 1/10 Iteration: 14900 Avg. Training loss: 4.2179 0.2825 sec/batch
# Epoch 1/10 Iteration: 15000 Avg. Training loss: 4.2702 0.2840 sec/batch
# Nearest to that: mib, suggested, proposition, cremated, toughest, retailer, gravimeters, say,
# Nearest to not: does, did, do, but, necessarily, bros, nightbreed, accommodates,
# Nearest to also: see, list, blacklisting, osu, hipparchus, ofc, irvine, pocketing,
# Nearest to he: caller, ceau, where, vengeance, celeste, tribesmen, nihonshoki, himself,
# Nearest to all: pollinator, almost, purdue, crankshaft, lydia, functions, monitoring, invisibility,
# Nearest to used: commonly, extensively, effigies, term, sony, widely, integers, serviced,
# Nearest to i: ii, am, t, think, myself, escobar, grad, tell,
# Nearest to when: makeshift, kidman, contemplated, mitra, insufficiently, dubai, sangre, asked,
# Nearest to woman: sonnets, quiescent, tarmac, casbah, corsican, butyrate, resident, defensemen,
# Nearest to dr: citation, hexafluoride, insurgent, thoroughbreds, constantinian, mummy, ehr, kovacs,
# Nearest to mainly: activate, iceberg, twelver, metroid, lingala, evangelism, emulsions, siais,
# Nearest to scale: large, blockades, primates, nehemiah, auctions, irradiation, rotors, neu,
# Nearest to test: helens, drops, endosperm, donors, aberdeen, romero, qurra, stolpe,
# Nearest to lived: parton, marshland, interactivity, eunuch, shameless, slips, domini, idaho,
# Nearest to road: theodosian, uncredited, ounces, kinetochores, reflective, reznor, browning, naturalist,
# Nearest to ocean: schalk, inalienable, landing, posed, atlantic, pacific, slumped, brochures,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.2163 0.1907 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.1936 0.2834 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.1639 0.2822 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.1891 0.2830 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.2017 0.2827 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.1076 0.2828 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.1362 0.2981 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.2252 0.2820 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.0524 0.2829 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.0802 0.2828 sec/batch
# Nearest to that: proposition, mib, suggested, cremated, say, solanas, gravimeters, presuppose,
# Nearest to not: does, did, do, but, necessarily, nightbreed, bros, accommodates,
# Nearest to also: see, list, pocketing, irvine, piedmont, creamy, blacklisting, osu,
# Nearest to he: celeste, where, himself, caller, received, vengeance, legnica, ceau,
# Nearest to all: pollinator, almost, lydia, ketones, invisibility, pissarro, shenanigans, purdue,
# Nearest to used: commonly, term, extensively, effigies, widely, serviced, grozny, sony,
# Nearest to i: ii, am, myself, think, escobar, grad, t, tell,
# Nearest to when: makeshift, kidman, mitra, contemplated, insufficiently, asked, dubai, ionian,
# Nearest to woman: sonnets, quiescent, tarmac, casbah, corsican, resident, tchad, defensemen,
# Nearest to dr: citation, hexafluoride, constantinian, thoroughbreds, insurgent, mummy, kovacs, sierpinski,
# Nearest to mainly: activate, iceberg, twelver, evangelism, metroid, emulsions, spymaster, boasts,
# Nearest to scale: large, blockades, primates, auctions, rotors, nehemiah, neu, irradiation,
# Nearest to test: helens, drops, endosperm, aberdeen, donors, romero, stolpe, jinn,
# Nearest to lived: parton, marshland, shameless, domini, interactivity, eunuch, slips, canonized,
# Nearest to road: theodosian, uncredited, ounces, kinetochores, browning, reflective, reznor, naturalist,
# Nearest to ocean: atlantic, schalk, inalienable, landing, posed, pacific, brochures, slumped,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.0959 0.3112 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.1745 0.2860 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.1608 0.2735 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.1498 0.2779 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.1477 0.2891 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.1500 0.2872 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.1627 0.2841 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.1768 0.3006 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.1725 0.2765 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 4.1629 0.2685 sec/batch
# Nearest to that: suggested, proposition, mib, cremated, postulated, argue, promotes, presuppose,
# Nearest to not: does, did, do, necessarily, but, nightbreed, accommodates, bros,
# Nearest to also: see, list, pocketing, blacklisting, hipparchus, osu, piedmont, creamy,
# Nearest to he: where, himself, vengeance, celeste, caller, received, legnica, ceau,
# Nearest to all: pollinator, almost, powers, lydia, ketones, invisibility, purdue, pissarro,
# Nearest to used: commonly, extensively, term, effigies, widely, serviced, grozny, remediation,
# Nearest to i: ii, am, myself, think, escobar, t, tell, nimzowitsch,
# Nearest to when: makeshift, kidman, contemplated, mitra, insufficiently, asked, sangre, prioritization,
# Nearest to woman: sonnets, quiescent, tarmac, casbah, corsican, resident, defensemen, butyrate,
# Nearest to dr: citation, hexafluoride, insurgent, constantinian, kovacs, sierpinski, thoroughbreds, ehr,
# Nearest to mainly: activate, twelver, iceberg, evangelism, emulsions, boasts, spymaster, metroid,
# Nearest to scale: large, blockades, primates, neu, auctions, rotors, nehemiah, irradiation,
# Nearest to test: helens, drops, endosperm, donors, aberdeen, stolpe, computational, jinn,
# Nearest to lived: parton, marshland, interactivity, eunuch, shameless, domini, slips, scheming,
# Nearest to road: theodosian, uncredited, kinetochores, ounces, browning, naturalist, reznor, reflective,
# Nearest to ocean: atlantic, landing, inalienable, schalk, posed, pacific, castilla, slumped,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.1790 0.2704 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.0789 0.2674 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.0919 0.2674 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.1874 0.2665 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.1831 0.2968 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.1985 0.2824 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 4.1674 0.2931 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 4.1843 0.2877 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.1565 0.2812 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 4.1466 0.2673 sec/batch
# Nearest to that: suggested, proposition, mib, cremated, postulated, solanas, claimed, say,
# Nearest to not: does, did, do, necessarily, but, nightbreed, bros, accommodates,
# Nearest to also: see, list, blacklisting, hipparchus, creamy, muscovite, osu, flattery,
# Nearest to he: where, himself, ceau, vengeance, caller, celeste, received, legnica,
# Nearest to all: pollinator, almost, pissarro, lydia, purdue, ketones, powers, monorail,
# Nearest to used: commonly, extensively, term, effigies, widely, serviced, remediation, grozny,
# Nearest to i: ii, am, myself, think, t, escobar, tell, you,
# Nearest to when: makeshift, kidman, contemplated, asked, mitra, insufficiently, sangre, prioritization,
# Nearest to woman: sonnets, quiescent, tarmac, casbah, butyrate, defensemen, corsican, resident,
# Nearest to dr: citation, hexafluoride, insurgent, constantinian, kovacs, timothy, thoroughbreds, ehr,
# Nearest to mainly: activate, twelver, iceberg, emulsions, evangelism, boasts, siais, metroid,
# Nearest to scale: large, blockades, primates, auctions, irradiation, casualties, advertisements, neu,
# Nearest to test: helens, drops, endosperm, donors, aberdeen, reposition, hoare, sumo,
# Nearest to lived: parton, marshland, eunuch, shameless, interactivity, domini, rabindranath, slips,
# Nearest to road: theodosian, uncredited, ounces, browning, kinetochores, naturalist, reznor, reflective,
# Nearest to ocean: landing, inalienable, atlantic, schalk, posed, castilla, pacific, brochures,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.1832 0.2776 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.1888 0.2745 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 4.1522 0.2802 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.1687 0.2717 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.1366 0.2753 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 4.1393 0.2751 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 4.0339 0.2749 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 4.0390 0.2761 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 4.1839 0.2771 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 4.1292 0.2746 sec/batch
# Nearest to that: proposition, suggested, mib, postulated, argue, promotes, solanas, say,
# Nearest to not: does, did, necessarily, do, but, nightbreed, accommodates, nor,
# Nearest to also: see, list, osu, blacklisting, disambiguation, ofc, muscovite, pocketing,
# Nearest to he: himself, vengeance, where, celeste, caller, ceau, nihonshoki, received,
# Nearest to all: pollinator, almost, pissarro, purdue, ketones, powers, lydia, srebrenica,
# Nearest to used: commonly, extensively, term, widely, effigies, refer, serviced, remediation,
# Nearest to i: ii, am, myself, think, t, hippopotamus, escobar, grad,
# Nearest to when: makeshift, kidman, contemplated, insufficiently, mitra, asked, dubai, prioritization,
# Nearest to woman: sonnets, quiescent, butyrate, casbah, tarmac, resident, defensemen, tchad,
# Nearest to dr: citation, hexafluoride, insurgent, leach, kovacs, constantinian, purported, mummy,
# Nearest to mainly: activate, twelver, iceberg, evangelism, emulsions, metroid, boasts, helier,
# Nearest to scale: large, blockades, primates, neu, advertisements, development, rotors, irradiation,
# Nearest to test: helens, drops, donors, endosperm, aberdeen, hoare, reposition, turntables,
# Nearest to lived: parton, marshland, shameless, eunuch, domini, slips, interactivity, rabindranath,
# Nearest to road: theodosian, uncredited, ounces, browning, kinetochores, reflective, offbeat, interscope,
# Nearest to ocean: atlantic, landing, inalienable, schalk, posed, pacific, castilla, winters,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 4.1309 0.2790 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 4.1229 0.2720 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 4.1569 0.2691 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 4.1474 0.2974 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 4.0875 0.2809 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 4.1868 0.2680 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 4.1476 0.2666 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 4.1722 0.2760 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 4.1674 0.2717 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 4.1531 0.2682 sec/batch
# Nearest to that: proposition, suggested, mib, argue, postulated, say, claimed, solanas,
# Nearest to not: does, did, necessarily, do, but, nightbreed, bros, nor,
# Nearest to also: see, list, osu, blacklisting, hipparchus, disambiguation, flattery, muscovite,
# Nearest to he: himself, where, caller, celeste, ceau, received, nihonshoki, dimitrov,
# Nearest to all: pollinator, almost, pissarro, lydia, powers, srebrenica, purdue, ketones,
# Nearest to used: commonly, extensively, term, effigies, widely, refer, serviced, remediation,
# Nearest to i: ii, am, myself, t, think, tell, grad, hippopotamus,
# Nearest to when: makeshift, kidman, contemplated, asked, mitra, insufficiently, prioritization, dubai,
# Nearest to woman: sonnets, quiescent, resident, tarmac, casbah, butyrate, young, corsican,
# Nearest to dr: citation, insurgent, hexafluoride, leach, kovacs, pixar, emile, mummy,
# Nearest to mainly: activate, iceberg, evangelism, twelver, emulsions, metroid, boasts, helier,
# Nearest to scale: large, blockades, primates, neu, rotors, irradiation, auctions, development,
# Nearest to test: helens, drops, endosperm, donors, aberdeen, reposition, sumo, turntables,
# Nearest to lived: parton, marshland, domini, slips, shameless, interactivity, simcity, eunuch,
# Nearest to road: theodosian, uncredited, browning, ounces, kinetochores, interscope, naturalist, reflective,
# Nearest to ocean: landing, atlantic, inalienable, schalk, posed, castilla, pacific, winters,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 4.1533 0.2712 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 4.1377 0.2672 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 4.1598 0.2674 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 4.1832 0.2742 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 4.1799 0.2749 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 4.0560 0.2682 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 4.1562 0.2657 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 4.0452 0.2510 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 4.1304 0.2499 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 4.1654 0.2592 sec/batch
# Nearest to that: suggested, proposition, argue, mib, claimed, postulated, promotes, say,
# Nearest to not: does, did, necessarily, do, but, bros, nor, nightbreed,
# Nearest to also: see, list, blacklisting, osu, hipparchus, flattery, disambiguation, muscovite,
# Nearest to he: himself, where, caller, nihonshoki, ceau, received, vengeance, celeste,
# Nearest to all: pollinator, almost, lydia, pissarro, powers, purdue, invisibility, insult,
# Nearest to used: commonly, extensively, term, refer, effigies, widely, remediation, serviced,
# Nearest to i: ii, am, myself, think, t, escobar, you, hippopotamus,
# Nearest to when: makeshift, kidman, contemplated, asked, mitra, insufficiently, prioritization, sangre,
# Nearest to woman: sonnets, tarmac, quiescent, resident, butyrate, casbah, defensemen, young,
# Nearest to dr: citation, hexafluoride, insurgent, leach, pixar, kovacs, mummy, fyodorovna,
# Nearest to mainly: activate, iceberg, evangelism, twelver, emulsions, boasts, analogical, lingala,
# Nearest to scale: large, blockades, irradiation, primates, neu, auctions, advertisements, development,
# Nearest to test: helens, donors, drops, endosperm, reposition, aberdeen, sumo, javelin,
# Nearest to lived: parton, marshland, slips, interactivity, shameless, eunuch, rabindranath, domini,
# Nearest to road: theodosian, uncredited, interscope, kinetochores, browning, offbeat, naturalist, ounces,
# Nearest to ocean: landing, atlantic, inalienable, schalk, posed, pacific, castilla, winters,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 4.1545 0.2919 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 4.1488 0.2723 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 4.1809 0.2590 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 4.1688 0.2525 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 4.1168 0.2737 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 4.0452 0.2657 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 4.1475 0.2566 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 4.0981 0.2563 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 4.1359 0.2637 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 4.1566 0.2547 sec/batch
# Nearest to that: suggested, proposition, argue, postulated, presuppose, claimed, fact, promotes,
# Nearest to not: does, did, necessarily, do, but, nor, nightbreed, bros,
# Nearest to also: see, list, osu, hipparchus, blacklisting, dentition, disambiguation, pocketing,
# Nearest to he: ceau, dimitrov, himself, where, nihonshoki, caller, vengeance, celeste,
# Nearest to all: almost, pollinator, lydia, pissarro, powers, ketones, srebrenica, purdue,
# Nearest to used: commonly, term, extensively, widely, effigies, refer, remediation, serviced,
# Nearest to i: ii, am, myself, think, t, escobar, hippopotamus, nimzowitsch,
# Nearest to when: makeshift, contemplated, kidman, mitra, asked, insufficiently, prioritization, dubai,
# Nearest to woman: sonnets, butyrate, defensemen, tarmac, resident, young, casbah, quiescent,
# Nearest to dr: citation, insurgent, hexafluoride, mummy, pixar, leach, kovacs, purported,
# Nearest to mainly: twelver, evangelism, activate, emulsions, iceberg, boasts, spymaster, lingala,
# Nearest to scale: large, blockades, neu, rotors, irradiation, casualties, primates, auctions,
# Nearest to test: helens, donors, endosperm, drops, reposition, aberdeen, hoare, computational,
# Nearest to lived: parton, marshland, slips, shameless, interactivity, domini, eunuch, milked,
# Nearest to road: theodosian, interscope, kinetochores, uncredited, browning, offbeat, naturalist, goldsmiths,
# Nearest to ocean: landing, atlantic, inalienable, schalk, posed, pacific, castilla, brochures,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 4.1459 0.2573 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 4.1123 0.2546 sec/batch
# ...
# Nearest to i: ii, e, am, world, war, my, think, iii,
# Nearest to when: asked, discussing, referring, occurs, especially, guessing, happens, arrived,
# Nearest to woman: nationality, man, defensemen, women, children, sonnets, noun, fertility,
# Nearest to dr: blok, physician, positioned, acc, rcn, kovacs, prof, zaman,
# Nearest to mainly: primarily, exclusively, mostly, emulsions, predominantly, largely, democratisation, analogical,
# Nearest to scale: large, scales, richter, tornadoes, rt, casualties, neu, yuga,
# Nearest to test: ban, tests, cricket, obsoletes, matches, hazardous, dumping, globes,
# Nearest to lived: short, eunuch, long, rabindranath, worked, living, monks, cannibal,
# Nearest to road: traffic, hildebrand, routes, hypocrisy, accident, extractive, racing, waterbury,
# Nearest to ocean: atlantic, pacific, indian, posed, castilla, intersputnik, ost, intelsat,
# Epoch 10/10 Iteration: 143100 Avg. Training loss: 3.9906 0.2505 sec/batch
# Epoch 10/10 Iteration: 143200 Avg. Training loss: 4.0374 0.2491 sec/batch
# Epoch 10/10 Iteration: 143300 Avg. Training loss: 3.8156 0.2489 sec/batch
# Epoch 10/10 Iteration: 143400 Avg. Training loss: 4.0447 0.2485 sec/batch
# Epoch 10/10 Iteration: 143500 Avg. Training loss: 4.0373 0.2482 sec/batch
# Epoch 10/10 Iteration: 143600 Avg. Training loss: 3.9963 0.2489 sec/batch
# Epoch 10/10 Iteration: 143700 Avg. Training loss: 3.9699 0.2500 sec/batch
# Epoch 10/10 Iteration: 143800 Avg. Training loss: 3.9694 0.2493 sec/batch
# Epoch 10/10 Iteration: 143900 Avg. Training loss: 3.9170 0.2485 sec/batch
# Epoch 10/10 Iteration: 144000 Avg. Training loss: 4.0135 0.2498 sec/batch
# Nearest to that: note, suggested, fact, argued, argue, noted, believe, argues,
# Nearest to not: did, does, necessarily, do, uncommon, confused, but, yet,
# Nearest to also: see, list, known, external, called, references, below, jost,
# Nearest to he: himself, popularize, his, where, wrote, mulhouse, montpellier, transmutation,
# Nearest to all: virtually, nearly, listing, almost, practically, things, assorted, everywhere,
# Nearest to used: describe, extensively, widely, refer, denote, term, commonly, frequently,
# Nearest to i: ii, e, am, think, my, world, war, iii,
# Nearest to when: asked, discussing, referring, especially, guessing, happens, occurs, arrived,
# Nearest to woman: nationality, man, children, defensemen, fertility, noun, women, sonnets,
# Nearest to dr: blok, positioned, physician, acc, kovacs, rcn, zaman, berimbau,
# Nearest to mainly: primarily, mostly, exclusively, emulsions, largely, predominantly, democratisation, analogical,
# Nearest to scale: large, scales, richter, tornadoes, casualties, rt, neu, fifths,
# Nearest to test: ban, tests, cricket, matches, obsoletes, hazardous, dumping, globes,
# Nearest to lived: short, eunuch, long, rabindranath, living, worked, monks, cannibal,
# Nearest to road: traffic, hildebrand, hypocrisy, routes, accident, extractive, waterbury, nestled,
# Nearest to ocean: atlantic, pacific, indian, posed, intersputnik, castilla, ost, intelsat,
# Epoch 10/10 Iteration: 144100 Avg. Training loss: 4.0444 0.2519 sec/batch
# Epoch 10/10 Iteration: 144200 Avg. Training loss: 4.0147 0.2482 sec/batch
# Epoch 10/10 Iteration: 144300 Avg. Training loss: 4.0264 0.2495 sec/batch
# Epoch 10/10 Iteration: 144400 Avg. Training loss: 4.0498 0.2485 sec/batch
# Epoch 10/10 Iteration: 144500 Avg. Training loss: 4.0529 0.2486 sec/batch
# Epoch 10/10 Iteration: 144600 Avg. Training loss: 4.0078 0.2494 sec/batch
# Epoch 10/10 Iteration: 144700 Avg. Training loss: 3.9385 0.2489 sec/batch
# Epoch 10/10 Iteration: 144800 Avg. Training loss: 4.0232 0.2486 sec/batch
# Epoch 10/10 Iteration: 144900 Avg. Training loss: 4.0383 0.2477 sec/batch
# Epoch 10/10 Iteration: 145000 Avg. Training loss: 4.0172 0.2493 sec/batch
# Nearest to that: note, suggested, fact, argued, noted, argue, believe, suggest,
# Nearest to not: did, does, necessarily, do, uncommon, confused, but, yet,
# Nearest to also: see, list, known, external, called, references, links, below,
# Nearest to he: himself, where, montpellier, popularize, mulhouse, nihonshoki, also, transmutation,
# Nearest to all: virtually, nearly, almost, listing, practically, things, everywhere, assorted,
# Nearest to used: describe, extensively, widely, refer, term, denote, commonly, frequently,
# Nearest to i: ii, e, am, think, world, my, war, iii,
# Nearest to when: asked, discussing, referring, especially, arrived, occurs, guessing, happens,
# Nearest to woman: nationality, man, children, defensemen, fertility, noun, sonnets, women,
# Nearest to dr: blok, physician, positioned, acc, kovacs, rcn, zaman, caucuses,
# Nearest to mainly: primarily, mostly, exclusively, emulsions, largely, predominantly, democratisation, analogical,
# Nearest to scale: large, scales, richter, casualties, tornadoes, rt, neu, yuga,
# Nearest to test: ban, tests, cricket, hazardous, matches, dumping, obsoletes, globes,
# Nearest to lived: short, eunuch, long, rabindranath, monks, living, cannibal, worked,
# Nearest to road: traffic, hildebrand, hypocrisy, routes, accident, nestled, waterbury, extractive,
# Nearest to ocean: atlantic, pacific, indian, posed, intersputnik, castilla, ost, intelsat,
# Epoch 10/10 Iteration: 145100 Avg. Training loss: 3.9899 0.2508 sec/batch
# Epoch 10/10 Iteration: 145200 Avg. Training loss: 4.0324 0.2482 sec/batch
# Epoch 10/10 Iteration: 145300 Avg. Training loss: 4.0280 0.2492 sec/batch
# Epoch 10/10 Iteration: 145400 Avg. Training loss: 4.0095 0.2484 sec/batch
# Epoch 10/10 Iteration: 145500 Avg. Training loss: 4.0383 0.2486 sec/batch
# Epoch 10/10 Iteration: 145600 Avg. Training loss: 4.0179 0.2486 sec/batch
# Epoch 10/10 Iteration: 145700 Avg. Training loss: 3.9866 0.2495 sec/batch
# Epoch 10/10 Iteration: 145800 Avg. Training loss: 3.9190 0.2490 sec/batch
# Epoch 10/10 Iteration: 145900 Avg. Training loss: 4.0093 0.2472 sec/batch
# Epoch 10/10 Iteration: 146000 Avg. Training loss: 3.9993 0.2488 sec/batch
# Nearest to that: note, suggested, argued, argue, fact, believe, noted, suggest,
# Nearest to not: did, does, necessarily, do, uncommon, confused, but, yet,
# Nearest to also: see, list, known, external, called, references, below, links,
# Nearest to he: himself, popularize, where, nihonshoki, acknowledges, thoroughbred, montpellier, cheltenham,
# Nearest to all: virtually, nearly, almost, listing, practically, things, except, assorted,
# Nearest to used: describe, extensively, widely, refer, denote, commonly, term, frequently,
# Nearest to i: ii, e, am, my, world, think, war, iii,
# Nearest to when: asked, discussing, referring, occurs, guessing, especially, happens, arrived,
# Nearest to woman: nationality, man, fertility, defensemen, children, sonnets, noun, women,
# Nearest to dr: blok, physician, positioned, acc, kovacs, rcn, zaman, mummy,
# Nearest to mainly: primarily, mostly, exclusively, emulsions, largely, predominantly, democratisation, due,
# Nearest to scale: large, scales, richter, casualties, rt, tornadoes, neu, fifths,
# Nearest to test: ban, tests, obsoletes, cricket, hazardous, dumping, matches, globes,
# Nearest to lived: short, eunuch, long, monks, living, inhabited, rabindranath, worked,
# Nearest to road: traffic, hildebrand, hypocrisy, accident, routes, vehicles, nestled, extractive,
# Nearest to ocean: atlantic, indian, pacific, posed, ost, castilla, intersputnik, intelsat,
# Epoch 10/10 Iteration: 146100 Avg. Training loss: 3.9494 0.2508 sec/batch
# Epoch 10/10 Iteration: 146200 Avg. Training loss: 4.0098 0.2496 sec/batch
# Epoch 10/10 Iteration: 146300 Avg. Training loss: 3.9759 0.2486 sec/batch
# Epoch 10/10 Iteration: 146400 Avg. Training loss: 3.9752 0.2503 sec/batch
# Epoch 10/10 Iteration: 146500 Avg. Training loss: 4.0667 0.2482 sec/batch
# Epoch 10/10 Iteration: 146600 Avg. Training loss: 3.7494 0.2484 sec/batch
# Epoch 10/10 Iteration: 146700 Avg. Training loss: 3.6626 0.2471 sec/batch
# Epoch 10/10 Iteration: 146800 Avg. Training loss: 3.8922 0.2482 sec/batch
# Epoch 10/10 Iteration: 146900 Avg. Training loss: 3.7985 0.2477 sec/batch
# Epoch 10/10 Iteration: 147000 Avg. Training loss: 3.9195 0.2484 sec/batch
# Nearest to that: note, suggested, argued, argue, fact, suggest, believe, announced,
# Nearest to not: did, does, necessarily, do, uncommon, but, confused, yet,
# Nearest to also: see, list, known, called, he, external, references, but,
# Nearest to he: himself, where, also, whom, wrote, popularize, cheltenham, nihonshoki,
# Nearest to all: listing, nearly, virtually, almost, practically, things, assorted, everywhere,
# Nearest to used: describe, extensively, widely, refer, commonly, frequently, term, denote,
# Nearest to i: ii, e, am, world, my, think, war, said,
# Nearest to when: asked, discussing, referring, arrived, especially, occurs, happens, guessing,
# Nearest to woman: nationality, man, defensemen, children, women, fertility, noun, sonnets,
# Nearest to dr: physician, blok, positioned, acc, kovacs, zaman, rcn, character,
# Nearest to mainly: primarily, mostly, exclusively, emulsions, largely, predominantly, analogical, fond,
# Nearest to scale: large, scales, richter, casualties, rt, tornadoes, neu, numbers,
# Nearest to test: tests, ban, obsoletes, cricket, matches, hazardous, dumping, globes,
# Nearest to lived: short, eunuch, long, worked, story, rabindranath, living, return,
# Nearest to road: traffic, hildebrand, hypocrisy, routes, accident, donovan, waterbury, nestled,
# Nearest to ocean: atlantic, pacific, indian, posed, ost, castilla, intersputnik, intelsat,
# Epoch 10/10 Iteration: 147100 Avg. Training loss: 3.9918 0.2525 sec/batch
# Epoch 10/10 Iteration: 147200 Avg. Training loss: 4.0015 0.2486 sec/batch
# Epoch 10/10 Iteration: 147300 Avg. Training loss: 4.0392 0.2488 sec/batch
# Epoch 10/10 Iteration: 147400 Avg. Training loss: 3.9777 0.2483 sec/batch
# Epoch 10/10 Iteration: 147500 Avg. Training loss: 4.0518 0.2487 sec/batch
# Epoch 10/10 Iteration: 147600 Avg. Training loss: 4.0522 0.2491 sec/batch
# Epoch 10/10 Iteration: 147700 Avg. Training loss: 4.0644 0.2484 sec/batch
# Epoch 10/10 Iteration: 147800 Avg. Training loss: 4.0236 0.2486 sec/batch
# Epoch 10/10 Iteration: 147900 Avg. Training loss: 4.0277 0.2479 sec/batch
# Epoch 10/10 Iteration: 148000 Avg. Training loss: 3.8616 0.2484 sec/batch
# Nearest to that: note, argue, fact, suggested, argued, suggest, believe, announced,
# Nearest to not: did, does, necessarily, do, uncommon, confused, but, yet,
# Nearest to also: see, list, known, external, called, references, below, but,
# Nearest to he: himself, popularize, where, wrote, cheltenham, acknowledges, guangzhou, his,
# Nearest to all: nearly, virtually, listing, almost, practically, things, everywhere, except,
# Nearest to used: describe, extensively, widely, refer, commonly, frequently, term, denote,
# Nearest to i: ii, e, am, think, world, my, war, said,
# Nearest to when: asked, discussing, referring, arrived, happens, occurs, kidman, especially,
# Nearest to woman: nationality, man, defensemen, women, noun, fertility, children, sonnets,
# Nearest to dr: blok, physician, positioned, rcn, acc, zaman, kovacs, mummy,
# Nearest to mainly: primarily, mostly, exclusively, largely, emulsions, predominantly, democratisation, fond,
# Nearest to scale: large, scales, richter, casualties, rt, tornadoes, neu, numbers,
# Nearest to test: tests, ban, cricket, obsoletes, dumping, matches, hazardous, globes,
# Nearest to lived: short, eunuch, rabindranath, settled, long, worked, story, coney,
# Nearest to road: traffic, hildebrand, routes, hypocrisy, accident, nestled, silk, extractive,
# Nearest to ocean: atlantic, indian, pacific, posed, ost, castilla, intersputnik, station,
# Epoch 10/10 Iteration: 148100 Avg. Training loss: 3.9937 0.2518 sec/batch
# Epoch 10/10 Iteration: 148200 Avg. Training loss: 4.0130 0.2480 sec/batch
# Epoch 10/10 Iteration: 148300 Avg. Training loss: 3.9850 0.2485 sec/batch
# Epoch 10/10 Iteration: 148400 Avg. Training loss: 3.9568 0.2483 sec/batch
# Epoch 10/10 Iteration: 148500 Avg. Training loss: 3.9980 0.2482 sec/batch
# Epoch 10/10 Iteration: 148600 Avg. Training loss: 4.0150 0.2490 sec/batch
# Epoch 10/10 Iteration: 148700 Avg. Training loss: 4.0551 0.2486 sec/batch
# Epoch 10/10 Iteration: 148800 Avg. Training loss: 3.9665 0.2492 sec/batch
# Epoch 10/10 Iteration: 148900 Avg. Training loss: 4.0074 0.2492 sec/batch
# Epoch 10/10 Iteration: 149000 Avg. Training loss: 3.8312 0.2481 sec/batch
# Nearest to that: note, fact, argue, suggested, argued, believe, suggest, announced,
# Nearest to not: did, does, necessarily, do, uncommon, confused, but, yet,
# Nearest to also: see, list, known, external, called, references, below, links,
# Nearest to he: himself, where, wrote, cheltenham, popularize, whom, mulhouse, acknowledges,
# Nearest to all: virtually, nearly, almost, listing, practically, everywhere, things, assorted,
# Nearest to used: describe, extensively, widely, refer, commonly, denote, frequently, term,
# Nearest to i: ii, e, am, think, world, my, war, said,
# Nearest to when: asked, discussing, referring, happens, arrived, occurs, especially, kidman,
# Nearest to woman: nationality, children, man, women, noun, fertility, defensemen, sonnets,
# Nearest to dr: physician, blok, positioned, acc, kovacs, zaman, rcn, applicability,
# Nearest to mainly: primarily, mostly, exclusively, largely, emulsions, predominantly, democratisation, elas,
# Nearest to scale: large, scales, richter, tornadoes, rt, casualties, neu, numbers,
# Nearest to test: ban, tests, cricket, obsoletes, hazardous, matches, dumping, globes,
# Nearest to lived: short, eunuch, long, rabindranath, story, worked, settled, cannibal,
# Nearest to road: traffic, routes, hildebrand, hypocrisy, accident, vehicles, nestled, silk,
# Nearest to ocean: atlantic, indian, pacific, posed, ost, castilla, intersputnik, intelsat,
# Epoch 10/10 Iteration: 149100 Avg. Training loss: 3.8465 0.2519 sec/batch
# Epoch 10/10 Iteration: 149200 Avg. Training loss: 4.0042 0.2476 sec/batch
# Epoch 10/10 Iteration: 149300 Avg. Training loss: 3.9838 0.2488 sec/batch
# Epoch 10/10 Iteration: 149400 Avg. Training loss: 3.8428 0.2486 sec/batch
# Epoch 10/10 Iteration: 149500 Avg. Training loss: 4.0015 0.2507 sec/batch
# Epoch 10/10 Iteration: 149600 Avg. Training loss: 4.0348 0.2494 sec/batch
# Epoch 10/10 Iteration: 149700 Avg. Training loss: 3.9824 0.2485 sec/batch
# Epoch 10/10 Iteration: 149800 Avg. Training loss: 3.9651 0.2494 sec/batch
# Epoch 10/10 Iteration: 149900 Avg. Training loss: 3.9500 0.2486 sec/batch
# Epoch 10/10 Iteration: 150000 Avg. Training loss: 3.9622 0.2482 sec/batch
# Nearest to that: note, fact, argue, suggested, argued, suggest, believe, announced,
# Nearest to not: did, does, necessarily, do, uncommon, confused, but, until,
# Nearest to also: see, list, known, external, called, references, but, below,
# Nearest to he: himself, where, wrote, cheltenham, whom, popularize, his, guangzhou,
# Nearest to all: nearly, virtually, listing, almost, practically, things, everywhere, assorted,
# Nearest to used: describe, extensively, widely, refer, term, commonly, denote, frequently,
# Nearest to i: ii, e, am, think, my, world, war, iii,
# Nearest to when: asked, discussing, referring, arrived, happens, occurs, especially, guessing,
# Nearest to woman: nationality, man, children, noun, defensemen, women, fertility, sonnets,
# Nearest to dr: physician, blok, positioned, acc, rcn, character, kovacs, zaman,
# Nearest to mainly: primarily, mostly, exclusively, largely, emulsions, predominantly, democratisation, elas,
# Nearest to scale: large, scales, richter, casualties, rt, tornadoes, neu, numbers,
# Nearest to test: tests, ban, obsoletes, hazardous, cricket, dumping, matches, ozone,
# Nearest to lived: short, eunuch, long, rabindranath, worked, story, settled, monks,
# Nearest to road: traffic, routes, hildebrand, accident, vehicles, racing, hypocrisy, donovan,
# Nearest to ocean: atlantic, indian, pacific, posed, castilla, ost, intersputnik, intelsat,
# Epoch 10/10 Iteration: 150100 Avg. Training loss: 3.9899 0.2514 sec/batch
# Epoch 10/10 Iteration: 150200 Avg. Training loss: 4.0369 0.2487 sec/batch
# Epoch 10/10 Iteration: 150300 Avg. Training loss: 4.0683 0.2487 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-a4718e25bc97> in <module>()
#       1 viz_words = 500
#       2 tsne = TSNE()
# ----> 3 embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])
#
# /Users/dave/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in fit_transform(self, X, y)
#     882             Embedding of the training data in low-dimensional space.
#     883         """
# --> 884         embedding = self._fit(X)
#     885         self.embedding_ = embedding
#     886         return self.embedding_
#
# /Users/dave/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in _fit(self, X, skip_num_points)
#     787                           X_embedded=X_embedded,
#     788                           neighbors=neighbors_nn,
# --> 789                           skip_num_points=skip_num_points)
#     790
#     791     def _tsne(self, P, degrees_of_freedom, n_samples, random_state,
#
# /Users/dave/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in _tsne(self, P, degrees_of_freedom, n_samples, random_state, X_embedded, neighbors, skip_num_points)
#     845         opt_args['it'] = it + 1
#     846         params, kl_divergence, it = _gradient_descent(obj_func, params,
# --> 847                                                       **opt_args)
#     848         if self.verbose:
#     849             print("[t-SNE] KL divergence after %d iterations with early "
#
# /Users/dave/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in _gradient_descent(objective, p0, it, n_iter, objective_error, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, min_error_diff, verbose, args, kwargs)
#     386     for i in range(it, n_iter):
#     387         new_error, grad = objective(p, *args, **kwargs)
# --> 388         grad_norm = linalg.norm(grad)
#     389
#     390         inc = update * grad >= 0.0
#
# /Users/dave/anaconda3/lib/python3.5/site-packages/scipy/linalg/misc.py in norm(a, ord, axis, keepdims)
#     127     """
#     128     # Differs from numpy only in non-finite handling and the use of blas.
# --> 129     a = np.asarray_chkfinite(a)
#     130
#     131     # Only use optimized norms if axis and keepdims are not specified.
#
# /Users/dave/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#    1213     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#    1214         raise ValueError(
# -> 1215             "array must not contain infs or NaNs")
#    1216     return a
#    1217
#
# ValueError: array must not contain infs or NaNs

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f98e3593a546> in <module>()
#       1 fig, ax = plt.subplots(figsize=(14, 14))
#       2 for idx in range(viz_words):
# ----> 3     plt.scatter(*embed_tsne[idx, :], color='steelblue')
#       4     plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
#
# NameError: name 'embed_tsne' is not defined
